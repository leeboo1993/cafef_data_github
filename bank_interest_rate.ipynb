# %%
import asyncio
import re
import os
import json
import pandas as pd
from datetime import datetime, date
from pathlib import Path
from bs4 import BeautifulSoup
from playwright.async_api import async_playwright, TimeoutError as PlaywrightTimeoutError

# ============================================================
# CONFIG
# ============================================================
try:
    BASE_DIR = Path(__file__).resolve().parent
except NameError:
    BASE_DIR = Path(os.getcwd()).resolve()

SAVE_DIR = BASE_DIR / "deposit_rate"
SAVE_DIR.mkdir(parents=True, exist_ok=True)
MASTER_PATH = SAVE_DIR / "deposit_rate_all.json"
LOG_PATH = SAVE_DIR / "deposit_log.csv"

# ============================================================
# UTILITIES
# ============================================================

def load_log():
    if LOG_PATH.exists():
        return pd.read_csv(LOG_PATH)
    else:
        cols = ["date", "link", "json_file", "status", "rows", "timestamp"]
        return pd.DataFrame(columns=cols)

def save_log(df):
    df.to_csv(LOG_PATH, index=False, encoding="utf-8-sig")

def save_json(data, path):
    with open(path, "w", encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

async def safe_goto(page, url, max_retries=3, timeout=60000):
    for attempt in range(1, max_retries + 1):
        try:
            await page.goto(url, timeout=timeout)
            await page.wait_for_load_state("domcontentloaded", timeout=15000)
            return True
        except Exception as e:
            print(f"⚠️ Navigation attempt {attempt}/{max_retries} failed: {e}")
            await asyncio.sleep(2)
    return False

# ============================================================
# TABLE PARSER — dynamic version
# ============================================================

def parse_interest_table(html, fallback_date):
    """Extract deposit rate table with dynamic month handling and 'no_term'."""
    soup = BeautifulSoup(html, "html.parser")

    # --- Detect table date ---
    match = re.search(r"(\d{1,2}/\d{1,2}/\d{4})", soup.get_text(" ", strip=True))
    table_date = (
        datetime.strptime(match.group(1), "%d/%m/%Y").strftime("%Y-%m-%d")
        if match
        else fallback_date
    )

    # --- Find target table ---
    target_table = None
    for tbl in soup.find_all("table"):
        text = tbl.get_text(" ", strip=True).lower()
        if all(k in text for k in ["ngân", "tháng", "lãi suất"]):
            target_table = tbl
            break
    if not target_table:
        print("⚠️ No valid table found in page.")
        return None

    # --- Parse rows ---
    rows = target_table.find_all("tr")
    if len(rows) < 3:
        return None

    header_cells = rows[1].find_all("td")
    headers = ["bank"] + [
        re.sub(r"\s+", "_", c.get_text(strip=True).lower()) for c in header_cells[1:]
    ]

    data = []
    for row in rows[2:]:
        cells = row.find_all("td")
        if len(cells) < 2:
            continue
        bank = cells[0].get_text(strip=True).upper()

        # Extract numeric values per cell
        rates = []
        for c in cells[1:]:
            txt = c.get_text(strip=True).replace(",", ".")
            try:
                val = float(txt)
                if val > 100:
                    val = None
            except ValueError:
                val = None
            rates.append(val)

        record = {"date": table_date, "bank": bank}
        for i, h in enumerate(headers[1:]):
            record[h] = rates[i] if i < len(rates) else None
        data.append(record)

    df = pd.DataFrame(data)

    # --- Normalise columns ---
    rename_map = {}
    for col in df.columns:
        col_clean = col.lower().strip()
        if "tháng" in col_clean:
            # e.g. "24_tháng" → "24m"
            m = re.search(r"(\d+)", col_clean)
            if m:
                rename_map[col] = f"{m.group(1)}m"
        elif "không" in col_clean or "kỳ_hạn" in col_clean:
            rename_map[col] = "no_term"

    df = df.rename(columns=rename_map)

    # --- Clean numeric values ---
    for c in [x for x in df.columns if re.match(r"^\d+m$", x) or x == "no_term"]:
        df[c] = (
            df[c]
            .astype(str)
            .str.replace("%", "", regex=False)
            .str.replace(",", ".", regex=False)
            .str.strip()
        )
        df[c] = pd.to_numeric(df[c], errors="coerce")
        df.loc[df[c] > 100, c] = None

    # --- Final clean ---
    df = df.where(pd.notnull(df), None)
    return df

# ============================================================
# MAIN SCRAPER
# ============================================================

async def scrape_vietnamnet_interest(start_date=None, end_date=None, headless=True):
    df_log = load_log()
    existing_dates = set(df_log["date"].dropna().unique())

    start_dt = datetime.strptime(start_date, "%Y-%m-%d") if start_date else None
    end_dt = datetime.strptime(end_date, "%Y-%m-%d") if end_date else None

    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=headless)
        page = await browser.new_page()

        base = "https://vietnamnet.vn"
        page_num = 1
        stop = False

        while True:
            url = f"https://vietnamnet.vn/tim-kiem-p{page_num}?q=Lãi suất ngân hàng hôm nay&od=2&bydaterang=all&newstype=all"
            print(f"🔍 Page {page_num}")
            if not await safe_goto(page, url):
                break
            try:
                await page.wait_for_selector("h3.vnn-title a", timeout=15000)
            except PlaywrightTimeoutError:
                print("⚠️ No search results found.")
                break

            soup = BeautifulSoup(await page.content(), "html.parser")
            links = []

            for a in soup.select("h3.vnn-title a[href]"):
                title = a.get_text(strip=True)
                href = a["href"]
                link = href if href.startswith("http") else base + href
                m = re.search(r"(\d{1,2}/\d{1,2}/\d{4})", title)
                if not m:
                    continue
                date_str = datetime.strptime(m.group(1), "%d/%m/%Y").strftime("%Y-%m-%d")
                if date_str in existing_dates:
                    continue
                dt = datetime.strptime(date_str, "%Y-%m-%d")
                if start_dt and dt < start_dt:
                    stop = True
                    break
                if end_dt and dt > end_dt:
                    continue
                links.append((date_str, link))

            if stop or not links:
                break

            for date_str, link in links:
                print(f"📄 Parsing {date_str} → {link}")
                key = datetime.strptime(date_str, "%Y-%m-%d").strftime("%y%m%d")
                json_path = SAVE_DIR / f"deposit_rate_{key}.json"
                status, rows = "fail", 0
                try:
                    if await safe_goto(page, link):
                        await page.wait_for_selector("table", timeout=15000)
                        html = await page.content()
                        df = parse_interest_table(html, date_str)
                        if df is not None and not df.empty:
                            data = df.to_dict(orient="records")
                            save_json(data, json_path)
                            rows = len(data)
                            status = "success"

                            # Update master JSON
                            if MASTER_PATH.exists():
                                master = json.load(open(MASTER_PATH, "r", encoding="utf-8"))
                            else:
                                master = []
                            master.extend(data)
                            save_json(master, MASTER_PATH)
                        else:
                            status = "no_table"
                except Exception as e:
                    print(f"⚠️ Error parsing {link}: {e}")
                    status = "fail"

                df_log.loc[len(df_log)] = [
                    date_str,
                    link,
                    json_path.name,
                    status,
                    rows,
                    datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
                ]
                save_log(df_log)

            page_num += 1
            await asyncio.sleep(1.2)

        await page.close()
        await browser.close()

    print("✅ Done. Logs synced and data saved.")

# ============================================================
# RUNNER
# ============================================================

def run_scraper(start_date=None, end_date=None, headless=True):
    try:
        loop = asyncio.get_event_loop()
        if loop.is_running():
            return asyncio.ensure_future(scrape_vietnamnet_interest(start_date, end_date, headless))
        else:
            loop.run_until_complete(scrape_vietnamnet_interest(start_date, end_date, headless))
    except RuntimeError:
        asyncio.run(scrape_vietnamnet_interest(start_date, end_date, headless))


# ============================================================
# MANUAL TEST EXAMPLE
# ============================================================

# if __name__ == "__main__":
#     run_scraper(start_date="2025-09-01", end_date="2025-10-25", headless=True)

# %%
await run_scraper()
# Out:
# 🔍 Page 1
# 📄 Parsing 2025-09-26 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-26-9-2025-ky-han-duoi-6-thang-cao-nhat-4-7-nam-2446223.html
# 📄 Parsing 2025-09-25 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-25-9-2025-lai-suat-huy-dong-9-nam-danh-cho-ai-2445835.html
# 📄 Parsing 2025-09-24 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-24-9-2025-ba-ngan-hang-co-lai-suat-tu-6-nam-2445539.html
# 📄 Parsing 2025-09-23 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-23-9-2025-nha-bang-tang-lai-suat-len-6-1-nam-2445235.html
# 📄 Parsing 2025-09-22 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-22-9-2025-gui-5-ty-dong-nhan-lai-6-5-the-nao-2444831.html
# 📄 Parsing 2025-09-19 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-19-9-2025-nha-bang-huy-dong-von-tra-lai-suat-7-nam-2444069.html
# 📄 Parsing 2025-09-18 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-18-9-2025-so-sanh-lai-tien-gui-o-nhom-ngan-hang-big4-2443723.html
# 📄 Parsing 2025-09-17 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-17-9-2025-nha-bang-hiem-hoi-duy-tri-lai-suat-6-2443331.html
# 📄 Parsing 2025-09-16 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-16-9-2025-ky-han-12-thang-cao-nhat-5-95-nam-2442903.html
# 📄 Parsing 2025-09-15 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-15-9-2025-nha-bang-tang-toi-0-8-lai-suat-2442529.html
# 📄 Parsing 2025-09-12 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-12-9-2025-soi-nha-bang-dan-dau-ky-han-6-12-thang-2441714.html
# 📄 Parsing 2025-09-11 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-11-9-2025-nha-bang-dau-tien-dieu-chinh-lai-suat-2441400.html
# 📄 Parsing 2025-09-10 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-10-9-2025-de-dat-tang-lai-suat-de-keo-khach-2440952.html
# 📄 Parsing 2025-09-09 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-9-9-2025-tang-them-1-lai-suat-neu-gui-online-2440531.html
# 📄 Parsing 2025-09-08 → https://vietnamnet.vn/lai-suat-ngan-hang-8-9-2025-lai-suat-huy-dong-thuc-te-khac-xa-niem-yet-2440151.html
# 📄 Parsing 2025-09-05 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-5-9-2025-ba-nha-bang-tien-sat-lai-suat-tran-2439475.html
# 📄 Parsing 2025-09-04 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-4-9-2025-ky-han-3-thang-lai-cao-nhat-4-55-nam-2439016.html
# 📄 Parsing 2025-09-03 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-3-9-2025-nguoi-gia-tren-80-tuoi-duoc-tang-them-0-4-2438720.html
# 📄 Parsing 2025-08-29 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-29-8-2025-bao-nhieu-ngan-hang-niem-yet-tren-6-2437342.html
# 📄 Parsing 2025-08-28 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-28-8-2025-ngan-hang-big4-duy-nhat-co-lai-suat-5-nam-2436942.html
# 🔍 Page 2
# 📄 Parsing 2025-08-27 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-27-8-2025-lai-suat-huy-dong-tang-nhe-trong-thang-8-2436519.html
# 📄 Parsing 2025-08-26 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-26-8-2025-cao-nhat-7-3-nam-khi-gui-tren-24-thang-2436091.html
# 📄 Parsing 2025-08-25 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-25-8-2025-dieu-kien-de-dang-de-nhan-them-lai-suat-2435668.html
# 📄 Parsing 2025-08-21 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-21-8-2025-nha-bang-nao-tra-lai-tien-gui-6-8-2434310.html
# 📄 Parsing 2025-08-20 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-20-8-2025-ngan-hang-0-dong-dan-dau-ve-lai-suat-2433881.html
# 📄 Parsing 2025-08-19 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-19-8-2025-khach-hang-duoc-tang-them-toi-0-8-2433522.html
# 📄 Parsing 2025-08-18 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-18-8-2025-tang-them-0-3-lai-suat-dac-biet-2433024.html
# 📄 Parsing 2025-08-15 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-15-8-2025-big4-hut-luong-tien-gui-khung-du-lai-thap-2432196.html
# 📄 Parsing 2025-08-14 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-14-8-2025-tang-manh-mot-loat-ky-han-2431789.html
# 📄 Parsing 2025-08-13 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-13-8-2025-lai-suat-huy-dong-tang-tro-lai-2431443.html
# 📄 Parsing 2025-08-12 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-12-8-2025-lai-suat-huy-dong-6-8-nam-danh-cho-ai-2431044.html
# 📄 Parsing 2025-08-11 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-11-8-2025-dong-loat-dieu-chinh-0-1-2430704.html
# 📄 Parsing 2025-08-08 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-8-8-2025-lai-suat-ky-han-15-va-18-thang-cao-nhat-2429848.html
# 📄 Parsing 2025-08-07 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-7-8-2025-gui-tien-duoi-6-thang-lai-cao-nhat-4-7-2429513.html
# 📄 Parsing 2025-08-06 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-6-8-2025-gui-100-trieu-nhan-ngay-lai-suat-6-8-nam-2429142.html
# 📄 Parsing 2025-08-04 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-4-8-2025-san-pham-tien-gui-moi-lai-cao-nhat-6-nam-2428410.html
# 📄 Parsing 2025-08-01 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-1-8-2025-lai-suat-huy-dong-ngan-hang-nao-cao-nhat-2427385.html
# 📄 Parsing 2025-07-31 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-31-7-2025-bat-ngo-tang-manh-sau-1-nam-2427245.html
# 🔍 Page 3
# 📄 Parsing 2025-07-30 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-30-7-2025-giam-mot-nua-so-voi-muc-dinh-2426906.html
# 📄 Parsing 2025-07-29 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-29-7-2025-lai-suat-cao-nhat-len-toi-9-65-2426593.html
# 📄 Parsing 2025-07-28 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-28-7-2025-tang-manh-lai-suat-huy-dong-ky-han-ngan-2426267.html
# 📄 Parsing 2025-07-25 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-25-7-2025-tang-lai-suat-huy-dong-ky-han-dai-2425546.html
# 📄 Parsing 2025-07-24 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-24-7-2025-3-nha-bang-tang-lai-tien-gui-tu-thang-7-2425207.html
# 📄 Parsing 2025-07-23 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-23-7-2025-chuyen-la-lung-tren-thi-truong-lai-suat-2424726.html
# 📄 Parsing 2025-07-22 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-22-7-2025-ngan-hang-nao-nhom-big4-co-muc-lai-4-9-2424369.html
# 📄 Parsing 2025-07-21 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-21-7-2025-ky-han-3-thang-cao-nhat-bao-nhieu-2423926.html
# 📄 Parsing 2025-07-18 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-18-7-2025-nha-bang-nao-niem-yet-lai-suat-6-nam-2423002.html
# 📄 Parsing 2025-07-17 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-17-7-2025-ngan-hang-thuong-lai-suat-bac-thang-2422650.html
# 📄 Parsing 2025-07-16 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-16-7-2025-tang-giam-trai-chieu-2422177.html
# 📄 Parsing 2025-07-15 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-15-7-2025-gui-tien-tu-100-trieu-tang-them-lai-suat-2421707.html
# 📄 Parsing 2025-07-14 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-14-7-2025-tang-manh-lai-suat-ky-han-ngan-2421328.html
# 📄 Parsing 2025-07-11 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-11-7-2025-nhom-ngan-hang-big4-cao-nhat-5-nam-2420413.html
# 📄 Parsing 2025-07-10 → https://vietnamnet.vn/lai-suat-ngan-hang-10-7-2025-loat-nha-bang-tang-them-lai-suat-2420019.html
# 📄 Parsing 2025-07-09 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-9-7-2025-ngan-hang-tang-lai-suat-huy-dong-2419528.html
# 📄 Parsing 2025-07-08 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-8-7-2025-ky-han-12-thang-khong-con-moc-6-nam-2418959.html
# 📄 Parsing 2025-07-07 → https://vietnamnet.vn/lai-suat-ngan-hang-7-7-2025-lai-suat-tien-gui-duoi-6-thang-cao-nhat-4-7-nam-2418846.html
# 📄 Parsing 2025-07-05 → https://vietnamnet.vn/lai-suat-ngan-hang-5-7-2025-ngan-hang-chuyen-giao-bat-buoc-co-lai-suat-cao-nhat-2418051.html
# 📄 Parsing 2025-07-04 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-4-7-2025-lai-suat-tien-gui-ngay-cuoi-tuan-tang-vot-2418079.html
# 🔍 Page 4
# 📄 Parsing 2025-07-03 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-3-7-2025-lai-suat-lien-ngan-hang-bat-tang-manh-2417467.html
# 📄 Parsing 2025-07-02 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-2-7-2025-nha-bang-giam-0-1-nam-2417303.html
# 📄 Parsing 2025-07-01 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-1-7-2025-ngan-hang-dau-tien-tang-lai-suat-2416950.html
# 📄 Parsing 2025-06-30 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-30-6-2025-ba-nha-bang-niem-yet-lai-suat-6-tro-len-2416466.html
# 📄 Parsing 2025-06-27 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-27-6-2025-lai-suat-lien-ngan-hang-tiep-tuc-giam-2415577.html
# 📄 Parsing 2025-06-26 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-26-6-2025-them-ngan-hang-dieu-chinh-lai-huy-dong-2415132.html
# 📄 Parsing 2025-06-25 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-25-6-2025-gui-tren-24-thang-cao-nhat-7-1-nam-2414709.html
# 📄 Parsing 2025-06-24 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-24-6-2025-nha-bang-nao-giu-lai-suat-lau-nhat-2414387.html
# 📄 Parsing 2025-06-23 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-23-6-2025-cao-nhat-6-1-2413925.html
# 📄 Parsing 2025-06-20 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-20-6-2025-giam-manh-0-5-ky-han-6-thang-2413251.html
# 📄 Parsing 2025-06-19 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-19-6-2025-lai-suat-ngan-hang-big4-dang-bao-nhieu-2412893.html
# 📄 Parsing 2025-06-18 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-18-6-2025-ngan-hang-nao-niem-yet-lai-suat-tu-6-nam-2412375.html
# 📄 Parsing 2025-06-17 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-17-6-2025-tang-manh-0-6-voi-tien-gui-truc-tuyen-2412109.html
# 📄 Parsing 2025-06-16 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-16-6-2025-ky-han-6-thang-cao-nhat-5-65-nam-2411757.html
# 📄 Parsing 2025-06-13 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-13-6-2025-ong-lon-lien-tiep-dieu-chinh-lai-suat-2411077.html
# 📄 Parsing 2025-06-12 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-12-6-2025-lai-suat-ngan-hang-duy-tri-on-dinh-2410645.html
# 📄 Parsing 2025-06-11 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-11-6-2025-gui-ky-han-1-thang-lai-cao-nhat-4-5-nam-2410118.html
# 📄 Parsing 2025-06-09 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-9-6-2025-ngan-hang-ngoai-nao-co-lai-suat-cao-nhat-2409475.html
# 📄 Parsing 2025-06-06 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-6-6-2025-dong-loat-tang-cac-ky-han-2408582.html
# 🔍 Page 5
# 📄 Parsing 2025-06-05 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-5-6-2025-them-ngan-hang-roi-moc-lai-suat-6-nam-2408197.html
# 📄 Parsing 2025-06-04 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-4-6-2025-dong-loat-giam-cac-ky-han-dai-2407775.html
# 📄 Parsing 2025-06-03 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-3-6-2025-lai-suat-dac-biet-cao-nhat-gan-10-nam-2407456.html
# 📄 Parsing 2025-06-02 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-2-6-2025-ba-nha-bang-ky-han-dai-cao-nhat-2407103.html
# 📄 Parsing 2025-05-29 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-29-5-2025-ky-han-ngan-cao-nhat-4-5-2405877.html
# 📄 Parsing 2025-05-27 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-27-5-2025-ngan-hang-dan-dau-ve-lai-suat-6-thang-2405149.html
# 📄 Parsing 2025-05-26 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-26-5-2025-ong-lon-lien-tiep-dieu-chinh-lai-suat-2404764.html
# 📄 Parsing 2025-05-23 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-23-5-2025-ong-lon-dieu-chinh-lai-suat-huy-dong-2403959.html
# 📄 Parsing 2025-05-22 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-22-5-2025-tang-lien-tiep-ky-han-ngan-2403595.html
# 📄 Parsing 2025-05-21 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-21-5-2025-gui-tien-ky-han-24-36-thang-lai-6-nam-2403223.html
# 📄 Parsing 2025-05-20 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-20-5-2025-gui-truc-tuyen-cao-hon-0-75-nam-2402834.html
# 📄 Parsing 2025-05-19 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-19-5-2025-ky-han-ngan-tang-them-0-2-2402487.html
# 📄 Parsing 2025-05-16 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-16-5-2025-tang-lai-suat-ky-han-ngan-2401589.html
# 📄 Parsing 2025-05-15 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-15-5-2025-thuong-them-lai-suat-toi-0-5-2401237.html
# 📄 Parsing 2025-05-14 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-14-5-2025-ky-han-6-thang-lai-suat-cao-nhat-5-65-2400896.html
# 📄 Parsing 2025-05-13 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-13-5-2025-lai-suat-huy-dong-6-6-2-nam-dang-o-dau-2400457.html
# 📄 Parsing 2025-05-12 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-12-5-2025-cac-ngan-hang-co-lai-suat-9-nam-tro-len-2400122.html
# 📄 Parsing 2025-05-09 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-9-5-2025-ky-han-12-thang-cao-nhat-5-95-nam-2399196.html
# 🔍 Page 6
# 📄 Parsing 2025-05-08 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-8-5-2025-tang-them-0-2-2398803.html
# 📄 Parsing 2025-05-07 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-7-5-2025-tiep-tuc-giam-manh-ky-han-ngan-2398471.html
# 📄 Parsing 2025-05-06 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-6-5-2025-giam-ky-han-ngan-tang-ky-han-dai-2398096.html
# 📄 Parsing 2025-05-05 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-5-5-2025-nha-bang-tang-o-tat-ca-ky-han-2397615.html
# 📄 Parsing 2025-04-29 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-29-4-2025-ap-dung-lai-suat-dac-biet-tang-0-2-nam-2396193.html
# 📄 Parsing 2025-04-28 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-28-4-2025-them-ngan-hang-roi-moc-lai-suat-6-nam-2395810.html
# 📄 Parsing 2025-04-25 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-25-4-2025-duy-nhat-1-noi-niem-yet-6-ky-han-12-thang-2394833.html
# 📄 Parsing 2025-04-24 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-24-4-2025-tang-tro-lai-co-ky-han-vuot-6-nam-2394472.html
# 📄 Parsing 2025-04-23 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-23-4-2025-ong-lon-tang-lai-tien-gui-0-1-2394096.html
# 📄 Parsing 2025-04-22 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-22-4-2025-cao-nhat-6-1-2393715.html
# 📄 Parsing 2025-04-21 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-21-4-2025-nha-bang-nao-niem-yet-6-tro-len-2393322.html
# 📄 Parsing 2025-04-18 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-18-4-2025-bat-tang-toi-0-75-2392399.html
# 📄 Parsing 2025-04-17 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-17-4-2025-tang-theo-gia-vang-2392071.html
# 📄 Parsing 2025-04-16 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-16-4-2025-ky-han-3-thang-cao-nhat-4-4-nam-2391672.html
# 📄 Parsing 2025-04-15 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-15-4-2025-nha-bang-giam-sau-hon-1-nam-2391287.html
# 📄 Parsing 2025-04-14 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-14-4-2025-nha-bang-bat-ngo-tang-0-6-2390730.html
# 📄 Parsing 2025-04-12 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-12-4-2025-ky-han-3-thang-cao-nhat-4-4-2390246.html
# 📄 Parsing 2025-04-11 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-11-4-2025-nha-bang-lien-tiep-dieu-chinh-lai-suat-2389990.html
# 📄 Parsing 2025-04-10 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-10-4-2025-lai-tiet-kiem-12-thang-cao-nhat-6-05-2389549.html
# 📄 Parsing 2025-04-09 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-9-4-2025-bat-ngo-tang-toi-0-5-2389191.html
# 🔍 Page 7
# 📄 Parsing 2025-04-08 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-8-4-2025-ngan-hang-ngoai-giam-manh-2388809.html
# 📄 Parsing 2025-04-04 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-4-4-2025-ngan-hang-thu-26-giam-lai-suat-huy-dong-2387775.html
# 📄 Parsing 2025-04-03 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-3-4-2025-lai-suat-dac-biet-cao-nhat-9-65-nam-2386985.html
# 📄 Parsing 2025-04-02 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-2-4-2025-cach-co-lai-suat-tren-6-nam-2386927.html
# 📄 Parsing 2025-04-01 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-1-4-2025-gui-duoi-100-trieu-dong-lai-suat-4-6-nam-2386469.html
# 📄 Parsing 2025-03-31 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-31-3-2025-cao-nhat-o-mot-ong-lon-la-5-7-2386069.html
# 📄 Parsing 2025-03-28 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-28-3-2025-dieu-chinh-muc-lai-tien-gui-cao-nhat-2385234.html
# 📄 Parsing 2025-03-27 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-27-3-2025-gui-truc-tuyen-cao-hon-den-0-6-tai-quay-2384846.html
# 📄 Parsing 2025-03-26 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-26-3-2025-muc-cao-nhat-7-1-nam-2384515.html
# 📄 Parsing 2025-03-25 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-25-3-2025-khong-nha-bang-nao-tang-lai-suat-2384037.html
# 📄 Parsing 2025-03-24 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-24-3-2025-nha-bang-nao-co-lai-suat-tren-6-2383636.html
# 📄 Parsing 2025-03-21 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-21-3-2025-nha-bang-lan-thu-3-giam-lai-suat-2382824.html
# 📄 Parsing 2025-03-20 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-20-3-2025-nha-bang-nao-niem-yet-tu-6-nam-2382474.html
# 📄 Parsing 2025-03-19 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-19-3-2025-bat-ngo-tang-tro-lai-2382115.html
# 📄 Parsing 2025-03-18 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-18-3-2025-ngan-hang-nao-vua-giam-lai-suat-huy-dong-2381801.html
# 📄 Parsing 2025-03-17 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-17-3-2025-lai-suat-cao-nhat-gan-10-nam-2381336.html
# 📄 Parsing 2025-03-14 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-14-3-2025-lai-suat-cao-nhat-6-4-nam-2380567.html
# 📄 Parsing 2025-03-13 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-13-3-2025-giam-uu-dai-voi-gioi-sieu-giau-2380131.html
# 📄 Parsing 2025-03-12 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-12-3-2025-muc-tren-6-nam-chi-con-1-nha-bang-2379763.html
# 📄 Parsing 2025-03-11 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-11-3-2025-ngan-hang-big4-dieu-chinh-lai-suat-2379350.html
# 🔍 Page 8
# 📄 Parsing 2025-03-10 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-10-3-2025-ong-lon-chinh-thuc-dieu-chinh-2378970.html
# 📄 Parsing 2025-03-07 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-7-3-2025-giam-manh-ngay-cang-it-muc-lai-6-2378262.html
# 📄 Parsing 2025-03-06 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-6-3-2025-nha-bang-ngoai-cung-giam-lai-suat-2377865.html
# 📄 Parsing 2025-03-05 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-5-3-2025-loat-nha-bang-giam-lai-suat-tu-thang-3-2377504.html
# 📄 Parsing 2025-03-04 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-4-3-2025-noi-giam-manh-noi-co-dong-thai-la-2377141.html
# 📄 Parsing 2025-03-03 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-3-3-2025-nong-cuoc-dua-giam-lai-suat-2376717.html
# 📄 Parsing 2025-02-28 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-28-2-2025-them-loat-ngan-hang-roi-moc-6-nam-2375863.html
# 📄 Parsing 2025-02-27 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-27-2-2025-o-dau-co-lai-suat-huy-dong-tu-6-nam-2375533.html
# 📄 Parsing 2025-02-26 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-26-2-2025-giam-nhanh-roi-moc-6-nam-2375105.html
# 📄 Parsing 2025-02-25 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-25-2-2025-nha-bang-nao-tang-lai-suat-huy-dong-2374645.html
# 📄 Parsing 2025-02-24 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-24-2-2025-nhom-big4-cao-nhat-5-nam-2374270.html
# 📄 Parsing 2025-02-21 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-21-2-2025-ky-han-3-thang-cao-nhat-bao-nhieu-2373518.html
# 📄 Parsing 2025-02-20 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-20-2-2025-mot-nha-bang-bat-ngo-tang-lai-suat-2373084.html
# 📄 Parsing 2025-02-19 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-19-2-2025-vua-doi-ten-nha-bang-tang-luon-lai-suat-2372689.html
# 📄 Parsing 2025-02-18 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-18-2-2025-lai-suat-huy-dong-cao-nhat-con-6-5-nam-2372326.html
# 📄 Parsing 2025-02-17 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-17-2-2025-ky-han-6-thang-cao-nhat-bao-nhieu-2371907.html
# 📄 Parsing 2025-02-14 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-14-2-2025-lai-suat-ky-han-12-thang-o-dau-cao-nhat-2371263.html
# 📄 Parsing 2025-02-13 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-13-2-2025-tang-ky-han-dai-2370886.html
# 📄 Parsing 2025-02-12 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-12-2-2025-lai-suat-dac-biet-danh-cho-ai-2370568.html
# 📄 Parsing 2025-02-11 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-11-2-2025-cao-nhat-len-toi-7-2-nam-2370257.html
# 🔍 Page 9
# 📄 Parsing 2025-02-10 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-10-2-2025-them-ngan-hang-giam-lai-suat-huy-dong-2369920.html
# 📄 Parsing 2025-02-07 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-7-2-2025-ky-han-9-thang-tang-manh-0-9-2369187.html
# 📄 Parsing 2025-02-06 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-6-2-2025-gui-ky-han-ngan-o-dau-lai-cao-nhat-2368913.html
# 📄 Parsing 2025-02-05 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-5-2-2025-lai-suat-huy-dong-cao-nhat-6-8-nam-2368506.html
# 📄 Parsing 2025-02-04 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-lai-suat-huy-dong-tang-theo-lai-suat-lien-ngan-hang-2368212.html
# 📄 Parsing 2025-02-03 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-3-2-2025-ngan-hang-giam-lai-suat-dau-nam-moi-2367942.html
# 📄 Parsing 2025-01-24 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-24-1-2025-dong-loat-tang-truoc-nghi-tet-2366208.html
# 📄 Parsing 2025-01-23 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-23-1-2025-ngan-hang-cong-bo-lai-suat-chop-nhoang-2365678.html
# 📄 Parsing 2025-01-22 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-22-1-2025-ky-han-ngan-gui-dau-de-co-lai-kich-tran-2365496.html
# 📄 Parsing 2025-01-21 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-21-1-2025-ky-han-3-thang-cao-nhat-2365128.html
# 📄 Parsing 2025-01-20 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-20-1-2025-thoa-thuan-lai-suat-khi-gui-tren-10-ty-2364854.html
# 📄 Parsing 2025-01-17 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-17-1-2025-mot-nha-bang-tang-manh-ky-han-ngan-2364087.html
# 📄 Parsing 2025-01-16 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-16-1-2025-gui-tiet-kiem-lai-suat-dac-biet-2363747.html
# 📄 Parsing 2025-01-15 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-15-1-2025-tang-cao-nhat-6-4-nam-2363411.html
# 📄 Parsing 2025-01-14 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-14-1-2025-ong-lon-giam-lai-suat-huy-dong-lan-2-2363035.html
# 📄 Parsing 2025-01-13 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-13-1-2025-nha-bang-chuyen-giao-quan-quan-2362665.html
# 📄 Parsing 2025-01-10 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-10-1-2025-tang-manh-2361890.html
# 📄 Parsing 2025-01-09 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-9-1-2025-duy-tri-tang-manh-2361519.html
# 📄 Parsing 2025-01-08 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-8-1-2025-lai-suat-huy-dong-bat-ngo-len-6-8-nam-2361123.html
# 🔍 Page 10
# 📄 Parsing 2025-01-07 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-7-1-2025-dong-loat-tang-ky-han-ngan-ap-sat-muc-tran-2360777.html
# 📄 Parsing 2025-01-06 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-6-1-2025-lai-suat-ky-han-ngan-cao-nhat-da-giam-2360390.html
# 📄 Parsing 2025-01-03 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-3-1-2025-nha-bang-tang-nhe-lai-suat-2359613.html
# 📄 Parsing 2025-01-02 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-2-1-2025-nhieu-nha-bang-dong-loat-tang-lai-suat-2359207.html
# 📄 Parsing 2024-12-30 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-30-12-2024-lo-dien-muc-lai-suat-cao-nhat-2024-2358014.html
# 📄 Parsing 2024-12-27 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-27-12-2024-nha-bang-nao-cao-nhat-2356960.html
# 📄 Parsing 2024-12-26 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-26-12-2024-soi-nha-bang-co-ky-han-12-thang-cao-nhat-2356475.html
# 📄 Parsing 2024-12-25 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-25-12-2024-gui-tien-ky-han-nao-lai-suat-7-2-nam-2356121.html
# 📄 Parsing 2024-12-24 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-24-12-2024-loat-lai-suat-uu-dai-chieu-khach-vip-2355747.html
# 📄 Parsing 2024-12-23 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-23-12-2024-ngan-hang-tang-lai-suat-dip-giang-sinh-2355378.html
# 📄 Parsing 2024-12-20 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-20-12-2024-gui-tien-6-thang-o-dau-lai-cao-nhat-2354509.html
# 📄 Parsing 2024-12-19 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-19-12-2024-gui-tien-ky-han-3-thang-o-dau-cao-nhat-2353997.html
# 📄 Parsing 2024-12-18 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-18-12-2024-ong-lon-vao-cuoc-dua-tang-lai-suat-2353595.html
# 📄 Parsing 2024-12-17 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-17-12-2024-them-ngan-hang-day-lai-suat-len-6-3-nam-2353183.html
# 📄 Parsing 2024-12-16 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-16-12-2024-nha-bang-bat-ngo-giam-lai-tien-gui-2352762.html
# 📄 Parsing 2024-12-13 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-13-12-2024-nha-bang-thu-13-tra-lai-suat-tu-6-nam-2351863.html
# 📄 Parsing 2024-12-11 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-11-12-2024-them-ngan-hang-giam-lai-suat-2351061.html
# 📄 Parsing 2024-12-10 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-10-12-2024-loat-nha-bang-o-at-tang-lai-suat-2350518.html
# 📄 Parsing 2024-12-09 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-9-12-2024-nha-bang-thu-6-tang-lai-suat-2350084.html
# 🔍 Page 11
# 📄 Parsing 2024-12-06 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-6-12-2024-lai-suat-6-5-nam-bat-ngo-bien-mat-2349137.html
# 📄 Parsing 2024-12-05 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-5-12-2024-them-nha-bang-tang-lai-suat-than-toc-2348715.html
# 📄 Parsing 2024-12-04 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-4-12-2024-ngan-hang-nho-du-dinh-lai-suat-2348355.html
# 📄 Parsing 2024-12-03 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-3-12-2024-lai-huy-dong-tang-than-toc-len-6-5-nam-2347977.html
# 📄 Parsing 2024-12-02 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-2-12-2024-muc-6-3-nam-bien-mat-2347603.html
# 📄 Parsing 2024-11-29 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-29-11-2024-them-ngan-hang-dua-tang-lai-suat-huy-dong-2346771.html
# 📄 Parsing 2024-11-28 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-28-11-2024-nha-bang-o-at-tang-lai-suat-huy-dong-2346355.html
# 📄 Parsing 2024-11-27 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-27-11-2024-them-ngan-hang-tang-manh-lai-huy-dong-2345989.html
# 📄 Parsing 2024-11-26 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-26-11-2024-gui-tien-duoi-6-thang-o-dau-lai-cao-nhat-2345608.html
# 📄 Parsing 2024-11-25 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-25-11-2024-them-ngan-hang-tang-lan-2-trong-thang-2345226.html
# 📄 Parsing 2024-11-22 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-22-11-2024-ky-han-6-thang-ngan-hang-nao-cao-nhat-2344478.html
# 📄 Parsing 2024-11-21 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-21-11-2024-loat-nha-bang-tra-lai-suat-huy-dong-tu-6-2344046.html
# 📄 Parsing 2024-11-20 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-20-11-2024-tang-manh-ky-han-duoi-6-thang-2343708.html
# 📄 Parsing 2024-11-19 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-19-11-2024-them-ngan-hang-tang-hai-lan-trong-thang-2343339.html
# 📄 Parsing 2024-11-18 → https://vietnamnet.vn/lai-suat-ngan-hang-18-11-2024-them-nha-bang-tang-lai-suat-vuot-6-nam-2342988.html
# 📄 Parsing 2024-11-15 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-15-11-2024-ong-lon-gay-bat-ngo-tang-tiep-moi-ky-han-2342176.html
# 📄 Parsing 2024-11-14 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-14-11-2024-lai-suat-huy-dong-vuot-dinh-6-3-nam-2341801.html
# 📄 Parsing 2024-11-13 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-13-11-2024-mot-nha-bang-tang-manh-can-moc-6-nam-2341441.html
# 📄 Parsing 2024-11-12 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-12-11-2024-them-nha-bang-vao-cuoc-dua-tang-lai-suat-2341097.html
# 📄 Parsing 2024-11-11 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-11-11-2024-agribank-vo-dich-nhom-big4-ky-han-ngan-2340759.html
# 🔍 Page 12
# 📄 Parsing 2024-11-08 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-8-11-2024-don-dap-ngan-hang-tang-lai-suat-huy-dong-2339957.html
# 📄 Parsing 2024-11-07 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-7-11-2024-ngan-hang-big4-lien-tuc-tang-lai-huy-dong-2339527.html
# 📄 Parsing 2024-11-06 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-6-11-2024-ky-han-18-thang-o-dau-cao-nhat-2339211.html
# 📄 Parsing 2024-11-05 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-5-11-2024-ngan-hang-lon-tang-lai-suat-huy-dong-2338761.html
# 📄 Parsing 2024-11-04 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-4-11-2024-xuat-hien-nha-bang-tang-lai-suat-lien-tiep-2338396.html
# 📄 Parsing 2024-11-01 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-1-11-2024-cb-noi-ly-do-phai-ha-lai-suat-huy-dong-2337635.html
# 📄 Parsing 2024-10-31 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-31-10-2024-lo-dien-5-ngan-hang-lai-suat-hon-6-nam-2337312.html
# 📄 Parsing 2024-10-30 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-30-10-2024-lai-suat-huy-dong-cao-nhat-6-35-nam-2336999.html
# 📄 Parsing 2024-10-29 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-29-10-2024-tang-manh-co-ngan-hang-can-moc-6-3-nam-2336629.html
# 📄 Parsing 2024-10-28 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-28-10-2024-ngan-hang-lon-tang-lai-suat-huy-dong-2336244.html
# 📄 Parsing 2024-10-26 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-26-10-2024-hai-nha-bang-tra-lai-cao-nhat-6-3-nam-2335648.html
# 📄 Parsing 2024-10-25 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-25-10-2024-goi-dien-gui-email-moi-lai-suat-cao-2335341.html
# 📄 Parsing 2024-10-24 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-24-10-2024-lai-suat-tien-gui-ky-han-ngan-tang-tiep-2334985.html
# 📄 Parsing 2024-10-23 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-23-10-2024-nhan-vien-moi-chao-lai-suat-cao-bat-ngo-2334576.html
# 📄 Parsing 2024-10-22 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-22-10-2024-lai-huy-dong-tang-dinh-noc-kich-tran-2334221.html
# 📄 Parsing 2024-10-21 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-21-10-2024-mot-ngan-hang-tang-lai-suat-dong-loat-2333866.html
# 📄 Parsing 2024-10-18 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-18-10-2024-7-ngan-hang-tra-lai-suat-6-tro-len-2332969.html
# 📄 Parsing 2024-10-17 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-17-10-2024-dai-gia-tang-lai-suat-ky-han-ngan-2332687.html
# 📄 Parsing 2024-10-16 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-16-10-2024-ong-lon-big4-tang-3-thang-lien-tiep-2332321.html
# 📄 Parsing 2024-10-15 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-15-10-2024-ky-han-6-thang-ngan-hang-nao-cao-nhat-2331984.html
# 🔍 Page 13
# 📄 Parsing 2024-10-14 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-14-10-2024-nha-bang-moi-chao-muc-6-3-nam-2331649.html
# 📄 Parsing 2024-10-11 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-11-10-2024-ngan-hang-nao-cao-nhat-trong-nhom-big4-2330858.html
# 📄 Parsing 2024-10-10 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-10-10-2024-dieu-kien-de-nhan-lai-suat-dac-biet-cao-2330516.html
# 📄 Parsing 2024-10-09 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-9-10-2024-da-tang-chung-lai-gui-tien-dau-lai-nhat-2330154.html
# 📄 Parsing 2024-10-08 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-8-10-2024-lo-ro-dieu-khac-biet-da-tang-da-cham-dut-2329769.html
# 📄 Parsing 2024-10-07 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-7-10-2024-mot-nha-bang-tang-manh-o-ky-han-dai-2329385.html
# 📄 Parsing 2024-10-04 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-4-10-2024-nha-bang-lan-dau-tang-manh-sau-3-thang-2328663.html
# 📄 Parsing 2024-10-03 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-3-10-2024-tiep-tuc-bat-dong-2328289.html
# 📄 Parsing 2024-10-02 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-2-10-2024-da-tang-chung-lai-nhnn-co-dong-thai-moi-2327879.html
# 📄 Parsing 2024-10-01 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-1-10-2024-ngan-hang-nao-co-lai-suat-tren-6-2327576.html
# 📄 Parsing 2024-09-30 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-30-9-2024-bat-ngo-ngan-hang-tang-3-lan-trong-thang-2327196.html
# 📄 Parsing 2024-09-27 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-27-9-2024-gui-tien-ky-han-6-thang-o-dau-cao-nhat-2326346.html
# 📄 Parsing 2024-09-26 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-26-9-2024-tang-vot-ap-sat-muc-cao-nhat-2325834.html
# 📄 Parsing 2024-09-25 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-25-9-2024-ngan-hang-dau-tien-tang-lai-huy-dong-lan-2-2325620.html
# 📄 Parsing 2024-09-24 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-24-9-2024-nha-bang-chi-tang-lai-suat-ky-han-ngan-2325247.html
# 📄 Parsing 2024-09-23 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-23-9-2024-5-nha-bang-tra-lai-gui-12-thang-cao-nhat-2324899.html
# 📄 Parsing 2024-09-20 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-20-9-2024-co-the-dam-phan-duoc-lai-suat-cao-nhat-2324003.html
# 📄 Parsing 2024-09-19 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-19-9-2024-ngan-hang-tiep-tuc-tang-lai-suat-huy-dong-2323693.html
# 📄 Parsing 2024-09-18 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-18-9-2024-nha-bang-thu-10-tang-lai-suat-trong-thang-2323270.html
# 📄 Parsing 2024-09-17 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-17-9-2024-van-dua-tang-them-nha-bang-nhap-cuoc-2322884.html
# 🔍 Page 14
# 📄 Parsing 2024-09-11 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-11-9-2024-lai-suat-tang-khi-tin-dung-tang-truong-kha-2320793.html
# 📄 Parsing 2024-09-10 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-10-9-2024-nha-bang-tang-lai-suat-duoi-kip-nhom-big4-2320371.html
# 📄 Parsing 2024-09-09 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-9-9-2024-bat-ngo-nha-bang-co-lai-cao-voi-ky-han-dai-2319864.html
# ⚠️ Error parsing https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-9-9-2024-bat-ngo-nha-bang-co-lai-cao-voi-ky-han-dai-2319864.html: Page.wait_for_selector: Timeout 15000ms exceeded.
# Call log:
#   - waiting for locator("table") to be visible
#
# 📄 Parsing 2024-09-06 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-6-9-2024-quan-quan-lai-suat-tien-gui-tiep-tuc-tang-2318919.html
# 📄 Parsing 2024-09-05 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-5-9-2024-bat-ngo-mot-nha-bang-tang-manh-len-muc-6-2318532.html
# 📄 Parsing 2024-09-04 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-4-9-2024-giam-manh-lai-tien-gui-sau-ky-nghi-le-2318193.html
# 📄 Parsing 2024-08-30 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-30-8-2024-hai-nha-bang-tang-manh-ky-han-ngan-2316940.html
# 📄 Parsing 2024-08-29 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-29-8-2024-nha-bang-am-tham-niem-yet-muc-lai-cao-2316565.html
# 📄 Parsing 2024-08-28 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-28-8-2024-ngan-hang-big4-tra-lai-cao-nhat-bao-nhieu-2316225.html
# 📄 Parsing 2024-08-27 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-27-8-2024-lai-suat-dac-biet-cho-khach-binh-dan-2315845.html
# 📄 Parsing 2024-08-26 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-26-8-2024-ong-lon-tiep-tuc-tang-lai-suat-huy-dong-2315467.html
# 📄 Parsing 2024-08-23 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-23-8-2024-gui-tiet-kiem-duoi-6-thang-o-dau-lai-cao-2314760.html
# 📄 Parsing 2024-08-22 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-22-8-2024-nha-bang-tra-lai-huy-dong-9-5-tang-tiep-2314352.html
# 📄 Parsing 2024-08-21 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-21-8-2024-tiep-da-tang-them-nha-bang-nhap-cuoc-2313969.html
# 📄 Parsing 2024-08-20 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-20-8-2024-ngan-hang-de-dat-tang-lai-suat-2313629.html
# 📄 Parsing 2024-08-19 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-19-8-2024-ngan-hang-cua-bau-hien-tang-lai-huy-dong-2313217.html
# 📄 Parsing 2024-08-16 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-16-8-2024-mot-nha-bang-bat-ngo-giam-lai-suat-2312284.html
# 📄 Parsing 2024-08-15 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-15-8-2024-phat-tin-hieu-ngam-ve-lai-suat-dac-biet-2311899.html
# 📄 Parsing 2024-08-14 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-14-8-2024-mot-ngan-hang-bat-ngo-giam-2311523.html
# 📄 Parsing 2024-08-13 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-13-8-2024-gui-tien-12-thang-lai-cao-nhat-len-6-nam-2311179.html
# 🔍 Page 15
# 📄 Parsing 2024-08-12 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-12-8-2024-them-ong-lon-tang-lai-suat-2310856.html
# 📄 Parsing 2024-08-09 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-9-8-2024-gui-tien-ky-han-6-9-thang-o-dau-cao-nhat-2310106.html
# 📄 Parsing 2024-08-08 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-8-8-2024-them-ong-lon-tang-lai-suat-huy-dong-2309778.html
# 📄 Parsing 2024-08-07 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-7-8-2024-quan-quan-lai-suat-cao-lai-bat-ngo-giam-2309369.html
# 📄 Parsing 2024-08-06 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-6-8-2024-nha-bang-tang-lai-suat-sau-3-thang-dung-im-2309000.html
# 📄 Parsing 2024-08-05 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-5-8-2024-chi-3-ngay-nha-bang-co-2-lan-tang-lai-suat-2308627.html
# 📄 Parsing 2024-08-02 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-2-8-2024-them-ngan-hang-tang-lai-suat-2307877.html
# 📄 Parsing 2024-08-01 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-1-8-2024-ong-lon-big-4-bat-ngo-tang-lai-suat-2307527.html
# 📄 Parsing 2024-07-31 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-31-7-2024-them-ngan-hang-tang-lai-suat-len-6-nam-2307176.html
# 📄 Parsing 2024-07-30 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-30-7-2024-ngan-hang-thu-18-tang-lai-suat-trong-thang-2306804.html
# 📄 Parsing 2024-07-29 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-29-7-2024-them-ngan-hang-tang-lai-huy-dong-vuot-6-2306469.html
# 📄 Parsing 2024-07-26 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-26-7-2024-ong-lon-lan-thu-hai-tang-lai-huy-dong-2305763.html
# 📄 Parsing 2024-07-25 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-25-7-2024-ngan-hang-nao-tra-lai-suat-6-2-nam-2305392.html
# 📄 Parsing 2024-07-24 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-24-7-2024-nha-bang-lien-tuc-tang-lai-suat-2305047.html
# 📄 Parsing 2024-07-23 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-23-7-2024-gui-tien-o-dau-de-co-lai-suat-6-tro-len-2304651.html
# 📄 Parsing 2024-07-22 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-22-7-2024-mot-nha-bang-tang-lai-suat-len-6-2-nam-2304329.html
# 📄 Parsing 2024-07-19 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-19-7-2024-nha-bang-tang-lai-suat-len-den-0-7-nam-2303492.html
# 📄 Parsing 2024-07-18 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-18-7-2024-hai-nha-bang-nhap-cuoc-tang-lai-huy-dong-2303098.html
# 📄 Parsing 2024-07-17 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-17-7-2024-ong-lon-tiep-tuc-tang-lai-suat-huy-dong-2302686.html
# 📄 Parsing 2024-07-16 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-16-7-2024-tang-lai-suat-lan-thu-hai-trong-thang-7-2302244.html
# 🔍 Page 16
# 📄 Parsing 2024-07-15 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-15-7-2024-da-tang-lai-suat-huy-dong-dang-cham-lai-2301873.html
# ⚠️ No valid table found in page.
# 📄 Parsing 2024-07-12 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-12-7-2024-them-ngan-hang-can-moc-lai-huy-dong-6-nam-2301040.html
# 📄 Parsing 2024-07-11 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-11-7-2024-gui-tien-tai-big4-lai-cao-nhat-5-2-nam-2300687.html
# 📄 Parsing 2024-07-10 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-10-7-2024-mb-tang-lai-suat-len-den-5-9-nam-2300277.html
# 📄 Parsing 2024-07-09 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-9-7-2024-ap-sat-muc-lai-suat-huy-dong-cao-nhat-2299847.html
# 📄 Parsing 2024-07-08 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-8-7-2024-nha-bang-lan-dau-tang-lai-suat-sau-4-thang-2299420.html
# 📄 Parsing 2024-07-05 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-5-7-2024-3-nha-bang-co-lai-tien-gui-3-thang-cao-nhat-2298616.html
# 📄 Parsing 2024-07-04 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-4-7-2024-lai-suat-huy-dong-tang-gan-kich-tran-2298163.html
# 📄 Parsing 2024-07-02 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-2-7-2024-tien-gui-ky-han-6-thang-cao-nhat-5-6-nam-2297384.html
# 📄 Parsing 2024-07-01 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-1-7-2024-nha-bang-bat-ngo-nguoc-dong-giam-lai-suat-2296988.html
# 📄 Parsing 2024-06-28 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-28-6-2024-nhieu-nha-bang-ap-sat-lai-suat-huy-dong-6-2296128.html
# 📄 Parsing 2024-06-27 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-27-6-2024-lai-suat-huy-dong-tu-5-nam-dang-ap-dao-2295743.html
# 📄 Parsing 2024-06-26 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-26-6-2024-loat-ngan-hang-tang-lai-suat-len-6-6-1-2295378.html
# 📄 Parsing 2024-06-25 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-25-6-2024-lai-suat-huy-dong-4-ong-lon-venh-nhau-2294893.html
# 📄 Parsing 2024-06-24 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-24-6-2024-big4-tang-lai-suat-khong-chinh-thuc-2294482.html
# 📄 Parsing 2024-06-21 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-21-6-2024-o-at-tang-lai-suat-huy-dong-2293776.html
# 📄 Parsing 2024-06-20 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-20-6-2024-8-nha-bang-lan-2-tang-lai-suat-trong-thang-2293365.html
# 📄 Parsing 2024-06-19 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-19-6-2024-tang-lai-suat-huy-dong-lan-thu-5-2292957.html
# 📄 Parsing 2024-06-18 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-18-6-2024-them-nha-bang-tang-lai-suat-huy-dong-2292622.html
# 🔍 Page 17
# 📄 Parsing 2024-06-17 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-17-6-2024-nha-bang-dan-dau-ve-lai-suat-ky-han-dai-2292226.html
# 📄 Parsing 2024-06-14 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-14-6-2024-ong-lon-tang-lai-suat-huy-dong-2291416.html
# 📄 Parsing 2024-06-13 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-13-6-2024-them-loat-nha-bang-tang-lai-suat-huy-dong-2291059.html
# 📄 Parsing 2024-06-12 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-12-6-2024-gui-tien-o-dau-duoc-9-5-nam-2290697.html
# 📄 Parsing 2024-06-11 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-11-6-2024-don-dap-tang-manh-lai-suat-huy-dong-2290320.html
# 📄 Parsing 2024-06-10 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-10-6-2024-mot-nha-bang-tang-manh-ky-han-ngan-2289939.html
# 📄 Parsing 2024-06-07 → https://vietnamnet.vn/lai-suat-ngan-hang-7-6-2024-them-2-nha-bang-nhap-cuoc-dua-tang-lai-suat-2289043.html
# 📄 Parsing 2024-06-06 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-6-6-2024-dong-loat-tang-soc-lai-suat-huy-dong-2288644.html
# 📄 Parsing 2024-06-05 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-5-6-2024-nha-bang-top-dau-lai-suat-cao-van-tang-tiep-2288156.html
# 📄 Parsing 2024-06-04 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-4-6-2024-nhom-nha-bang-vua-va-nho-o-at-tang-lai-suat-2287658.html
# 📄 Parsing 2024-06-03 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-3-6-2024-big4-dua-tang-lai-suat-huy-dong-2287182.html
# 📄 Parsing 2024-05-31 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-31-5-2024-them-hai-nha-bang-tang-lai-huy-dong-2286268.html
# 📄 Parsing 2024-05-30 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-30-5-2024-ong-lon-bat-ngo-giam-lai-suat-ve-muc-cu-2285904.html
# 📄 Parsing 2024-05-29 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-29-5-2024-ong-lon-tang-manh-lai-suat-2285492.html
# 📄 Parsing 2024-05-28 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-28-5-2024-them-nha-bang-nhap-cuoc-dua-tang-lai-suat-2285092.html
# 📄 Parsing 2024-05-27 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-27-5-2024-don-dap-tang-lai-suat-huy-dong-2284785.html
# 📄 Parsing 2024-05-24 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-24-5-2024-lo-dien-nha-bang-4-lan-tang-lai-huy-dong-2283869.html
# 📄 Parsing 2024-05-23 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-23-5-2024-them-nha-bang-tang-lan-thu-3-trong-thang-2283520.html
# 📄 Parsing 2024-05-22 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-22-5-2024-vua-tang-nha-bang-bat-ngo-ha-lai-suat-2283189.html
# 📄 Parsing 2024-05-21 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-21-5-2024-nha-bang-3-lan-tang-lai-suat-tu-dau-thang-2282837.html
# 🔍 Page 18
# 📄 Parsing 2024-05-20 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-20-5-2024-nha-bang-dau-tien-tra-lai-huy-dong-6-2-2282434.html
# 📄 Parsing 2024-05-17 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-17-5-2024-mot-nha-bang-tang-manh-lai-suat-huy-dong-2281672.html
# 📄 Parsing 2024-05-16 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-16-5-2024-nha-bang-tat-bat-dieu-chinh-tang-lai-suat-2281316.html
# 📄 Parsing 2024-05-15 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-15-5-2024-mot-ngan-hang-tang-lai-suat-ky-han-6-thang-2280943.html
# 📄 Parsing 2024-05-14 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-14-5-2024-nha-bang-nao-tra-lai-tien-gui-cao-nhat-2280541.html
# 📄 Parsing 2024-05-13 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-13-5-2024-ngan-hang-tang-lai-suat-sau-hon-1-nam-2280148.html
# 📄 Parsing 2024-05-09 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-9-5-2024-them-loat-nha-bang-tang-lai-suat-huy-dong-2278829.html
# 📄 Parsing 2024-05-07 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-7-5-2024-lai-suat-huy-dong-tiep-tuc-tang-2277898.html
# 📄 Parsing 2024-05-06 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-6-5-2024-dong-loat-tang-manh-lai-suat-huy-dong-2277549.html
# 📄 Parsing 2024-05-04 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-4-5-2024-nha-bang-lien-tuc-tang-lai-suat-2276969.html
# 📄 Parsing 2024-05-03 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-3-5-2024-lai-suat-ngan-hang-cho-bat-tang-2276595.html
# 📄 Parsing 2024-05-02 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-2-5-2024-nha-bang-dau-tien-tang-lai-suat-sau-nghi-le-2276223.html
# 📄 Parsing 2024-04-26 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-26-4-2024-noi-dai-danh-sach-nha-bang-tang-lai-suat-2274771.html
# 📄 Parsing 2024-04-25 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-25-4-2024-ong-lon-big4-tang-lai-suat-huy-dong-2274365.html
# 📄 Parsing 2024-04-24 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-24-4-2024-them-hai-ngan-hang-tang-lai-suat-2273915.html
# 📄 Parsing 2024-04-23 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-23-4-2024-lai-suat-huy-dong-co-tiep-tuc-tang-2273439.html
# 📄 Parsing 2024-04-19 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-19-4-2024-dong-loat-tang-co-ngan-hang-tang-lan-3-2272005.html
# 🔍 Page 19
# 📄 Parsing 2024-04-17 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-17-4-2024-giam-o-ngan-hang-co-lai-suat-cao-nhat-2271366.html
# 📄 Parsing 2024-04-16 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-16-4-2024-ngan-hang-big4-tang-lai-suat-huy-dong-2270960.html
# 📄 Parsing 2024-04-15 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-15-4-2024-mot-nha-bang-giam-xuong-thap-chua-tung-co-2270494.html
# 📄 Parsing 2024-04-11 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-11-4-2024-them-ngan-hang-tang-lai-huy-dong-2269303.html
# 📄 Parsing 2024-04-10 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-10-4-2024-don-dap-tang-lai-suat-huy-dong-2268937.html
# 📄 Parsing 2024-04-09 → https://vietnamnet.vn/lai-suat-ngan-hang-9-4-2024-ngan-hang-tang-lai-suat-lan-thu-2-lien-tiep-2268522.html
# 📄 Parsing 2024-04-08 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-8-4-2024-co-nha-bang-giam-tien-khong-con-o-at-do-ve-2268144.html
# 📄 Parsing 2024-04-05 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-5-4-2024-them-ngan-hang-tang-lai-huy-dong-2267321.html
# 📄 Parsing 2024-04-04 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-4-4-2024-them-nha-bang-bat-ngo-tang-lai-suat-2266936.html
# 📄 Parsing 2024-04-03 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-3-4-2024-lai-suat-cao-nhat-9-5-2266485.html
# 📄 Parsing 2024-04-02 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-2-4-2024-ong-lon-pha-day-bao-gio-bat-tang-2266068.html
# 📄 Parsing 2024-04-01 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-1-4-2024-ngan-hang-dau-tien-giam-lai-suat-thang-4-2265638.html
# 📄 Parsing 2024-03-29 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-29-3-2024-nhung-nha-bang-tien-phong-tang-lai-suat-2264789.html
# 📄 Parsing 2024-03-28 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-28-3-2024-van-co-nha-bang-giam-manh-lai-suat-2264421.html
# 📄 Parsing 2024-03-27 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-27-3-2024-them-ong-lon-tang-lai-suat-tat-ca-ky-han-2264023.html
# 📄 Parsing 2024-03-26 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-26-3-2024-loat-ngan-hang-tang-lai-suat-huy-dong-2263630.html
# 📄 Parsing 2024-03-25 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-25-3-2024-hai-ong-lon-giam-tiep-lai-suat-huy-dong-2263252.html
# 📄 Parsing 2024-03-22 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-22-3-2024-eximbank-bat-ngo-tang-lai-suat-huy-dong-2262380.html
# 📄 Parsing 2024-03-21 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-21-3-2024-chinh-thuc-xoa-so-lai-suat-tu-6-nam-2261939.html
# 🔍 Page 20
# 📄 Parsing 2024-03-20 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-20-3-2024-ngan-hang-nao-dang-tra-lai-suat-cao-nhat-2261496.html
# 📄 Parsing 2024-03-19 → https://vietnamnet.vn/lai-suat-ngan-hang-19-3-2024-bat-ngo-nha-bang-nho-tang-them-ong-lon-giam-2261087.html
# 📄 Parsing 2024-03-15 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-15-3-2024-mot-ong-lon-bat-ngo-giam-ve-muc-thap-nhat-2259721.html
# 📄 Parsing 2024-03-13 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-13-3-2024-ty-gia-ha-nhiet-lai-suat-se-ra-sao-2258956.html
# 📄 Parsing 2024-03-11 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-11-3-2024-lai-suat-dac-biet-10-danh-cho-ai-2258053.html
# 📄 Parsing 2024-03-08 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-8-3-2024-nha-bang-duy-nhat-tra-lai-suat-tren-6-nam-2257272.html
# 📄 Parsing 2024-03-07 → https://vietnamnet.vn/lai-suat-ngan-hang-7-3-2024-ngan-hang-0-dong-giam-2-lan-trong-3-ngay-2256904.html
# 📄 Parsing 2024-03-04 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-4-3-2024-2-nha-bang-mo-hang-giam-lai-suat-thang-3-2255618.html
# 📄 Parsing 2024-02-29 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-29-2-2024-don-dap-giam-lai-huy-dong-ngay-cuoi-thang-2254206.html
# 📄 Parsing 2024-02-27 → https://vietnamnet.vn/lai-suat-ngan-hang-27-2-2024-ngan-hang-lon-lan-dau-tien-giam-lai-tien-gui-2253394.html
# 📄 Parsing 2024-02-26 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-26-2-2024-ky-han-12-thang-ngan-hang-nao-cao-nhat-2252936.html
# 📄 Parsing 2024-02-20 → https://vietnamnet.vn/lai-suat-ngan-hang-20-2-2024-co-nha-bang-giam-3-ngay-lien-tiep-2250846.html
# 📄 Parsing 2024-02-16 → https://vietnamnet.vn/lai-suat-ngan-hang-16-2-2024-nha-bang-dau-tien-tang-lai-suat-sau-ky-nghi-tet-2249630.html
# 📄 Parsing 2024-02-06 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-6-2-2024-loat-nha-bang-o-at-giam-van-co-ky-han-tang-2247574.html
# 📄 Parsing 2024-02-05 → https://vietnamnet.vn/lai-suat-ngan-hang-5-2-2024-them-3-nha-bang-ha-mot-ong-lon-giam-manh-2247152.html
# 📄 Parsing 2024-02-01 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-1-2-2024-2-nha-bang-giam-manh-lai-suat-2245865.html
# 📄 Parsing 2024-01-30 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-30-1-2024-2-ong-lon-giam-tiep-lai-suat-van-do-day-2245169.html
# 📄 Parsing 2024-01-25 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-25-1-2024-lai-suat-dac-biet-giam-cao-nhat-10-2243457.html
# 📄 Parsing 2024-01-23 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-23-1-2024-them-loat-nha-bang-dua-ha-lai-suat-2242635.html
# 🔍 Page 21
# 📄 Parsing 2024-01-19 → https://vietnamnet.vn/lai-suat-ngan-hang-19-1-2024-them-loat-nha-bang-giam-lai-suat-2241205.html
# 📄 Parsing 2024-01-18 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-18-1-2024-nha-bang-thu-24-noi-got-giam-lai-suat-2240785.html
# 📄 Parsing 2024-01-17 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-17-1-2024-loat-ong-lon-giam-ve-muc-thap-ky-luc-2240428.html
# 📄 Parsing 2024-01-16 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-16-1-2024-5-nha-bang-tra-lai-suat-cao-nhat-cung-giam-2239998.html
# 📄 Parsing 2024-01-12 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-12-1-2024-duy-nhat-mot-ngan-hang-giam-lai-suat-2238527.html
# 📄 Parsing 2024-01-11 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-11-1-2024-co-them-nha-bang-tang-lai-suat-huy-dong-2238033.html
# 📄 Parsing 2024-01-04 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-4-1-2024-mot-ngan-hang-giam-soc-2234952.html
# 📄 Parsing 2024-01-03 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-3-1-2024-them-loat-nha-bang-giam-lai-suat-huy-dong-2234438.html
# 📄 Parsing 2023-12-28 → https://vietnamnet.vn/lai-suat-ngan-hang-ngay-28-12-2023-them-ngan-hang-tang-lai-suat-huy-dong-2232233.html
# 📄 Parsing 2023-12-26 → https://vietnamnet.vn/lai-suat-ngan-hang-26-12-2023-ong-lon-giam-nha-bang-nho-bat-ngo-tang-lai-suat-2231292.html
# 📄 Parsing 2023-12-21 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-21-12-2023-ngan-hang-tung-lai-suat-dac-biet-2229511.html
# 📄 Parsing 2023-12-19 → https://vietnamnet.vn/lai-suat-ngan-hang-19-12-2023-nha-bang-van-don-dap-ha-lai-suat-huy-dong-2228557.html
# 📄 Parsing 2023-12-14 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-14-12-2023-vib-va-vpbank-giam-lai-suat-2226776.html
# 📄 Parsing 2023-12-11 → https://vietnamnet.vn/lai-suat-ngan-hang-11-12-2023-them-ngan-hang-nhom-big4-giam-lai-suat-huy-dong-2225478.html
# 📄 Parsing 2023-12-08 → https://vietnamnet.vn/lai-suat-ngan-hang-8-12-2023-da-giam-van-chua-dung-2224412.html
# 📄 Parsing 2023-12-07 → https://vietnamnet.vn/lai-suat-ngan-hang-7-12-2023-them-loat-ngan-hang-giam-lai-suat-huy-dong-2223977.html
# 📄 Parsing 2023-11-30 → https://vietnamnet.vn/lai-suat-ngan-hang-30-11-2023-ong-lon-tra-lai-thap-nhat-van-tiep-tuc-giam-2221011.html
# 📄 Parsing 2023-11-28 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-28-11-2023-them-hai-nha-bang-giam-lai-suat-huy-dong-2220120.html
# 📄 Parsing 2023-11-24 → https://vietnamnet.vn/lai-suat-ngan-hang-24-11-2023-gui-bao-nhieu-tien-de-huong-10-5-nam-2218578.html
# 📄 Parsing 2023-11-23 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-23-11-2023-sacombank-giam-soc-lai-suat-huy-dong-2218093.html
# 🔍 Page 22
# 📄 Parsing 2023-11-22 → https://vietnamnet.vn/lai-suat-ngan-hang-ngay-22-11-2023-ky-han-nao-lai-cao-nhat-2217666.html
# 📄 Parsing 2023-11-21 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-21-11-2023-them-loat-ngan-hang-giam-lai-huy-dong-2217218.html
# 📄 Parsing 2023-11-20 → https://vietnamnet.vn/lai-suat-ngan-hang-hom-nay-20-11-2023-vua-tang-lai-suat-ngan-hang-lai-giam-2216760.html
# 📄 Parsing 2023-11-17 → https://vietnamnet.vn/lai-suat-ngan-hang-ngay-17-11-2023-lai-co-them-nha-bang-tang-lai-suat-2215909.html
# 📄 Parsing 2023-11-16 → https://vietnamnet.vn/lai-suat-ngan-hang-ngay-16-11-2023-giam-manh-o-nhom-nha-bang-tra-lai-suat-cao-2215446.html
# 📄 Parsing 2023-11-15 → https://vietnamnet.vn/lai-suat-ngan-hang-ngay-15-11-2023-them-ngan-hang-dua-lai-suat-ve-duoi-5-nam-2214980.html
# 📄 Parsing 2023-11-14 → https://vietnamnet.vn/lai-suat-ngan-hang-ngay-14-11-2023-ong-lon-bat-ngo-tang-lai-suat-huy-dong-2214592.html
# 📄 Parsing 2023-11-13 → https://vietnamnet.vn/lai-suat-ngan-hang-ngay-13-11-2023-ngan-hang-nguoc-dong-tang-lai-suat-huy-dong-2214181.html
# 📄 Parsing 2023-11-07 → https://vietnamnet.vn/lai-suat-ngan-hang-ngay-7-11-2023-loat-nha-bang-o-at-giam-lai-suat-huy-dong-2211845.html
# 📄 Parsing 2023-11-03 → https://vietnamnet.vn/lai-suat-ngan-hang-ngay-3-11-2023-dien-bien-bat-ngo-voi-lai-suat-huy-dong-2210415.html
# 📄 Parsing 2023-11-02 → https://vietnamnet.vn/lai-suat-ngan-hang-ngay-2-11-2023-them-ngan-hang-giam-manh-lai-suat-huy-dong-2209989.html
# 📄 Parsing 2023-10-31 → https://vietnamnet.vn/lai-suat-ngan-hang-ngay-31-10-2023-mot-nha-bang-bat-ngo-tang-manh-2208981.html
# 📄 Parsing 2023-10-27 → https://vietnamnet.vn/lai-suat-ngan-hang-27-10-2023-gui-ky-han-duoi-12-thang-o-dau-de-co-lai-nhat-2207365.html
# 📄 Parsing 2023-10-26 → https://vietnamnet.vn/lai-suat-ngan-hang-ngay-26-10-2023-gui-tien-o-dau-ky-han-nao-lai-6-4-nam-2206821.html
# 📄 Parsing 2023-10-25 → https://vietnamnet.vn/lai-suat-ngan-hang-25-10-2023-chi-1-nha-bang-giam-lai-suat-tiet-kiem-da-cham-day-2206371.html
# 📄 Parsing 2023-10-24 → https://vietnamnet.vn/lai-suat-ngan-hang-24-10-2023-them-loat-nha-bang-giam-ve-quanh-muc-tren-5-2205957.html
# 📄 Parsing 2023-10-23 → https://vietnamnet.vn/lai-suat-ngan-hang-ngay-23-10-2023-gui-tien-o-dau-de-co-lai-tren-6-nam-2205454.html
# 📄 Parsing 2023-10-20 → https://vietnamnet.vn/lai-suat-ngan-hang-20-10-2023-vietcombank-giam-lai-suat-xuong-thap-ky-luc-2204463.html
# 📄 Parsing 2023-10-19 → https://vietnamnet.vn/lai-suat-ngan-hang-19-10-2023-vib-va-sacombank-giam-lai-suat-huy-dong-2204011.html
# 📄 Parsing 2023-10-18 → https://vietnamnet.vn/lai-suat-ngan-hang-18-10-2023-hdbank-nam-a-bank-giam-lai-suat-lan-2-thang-10-2203529.html
# 🔍 Page 23
# 📄 Parsing 2023-10-17 → https://vietnamnet.vn/lai-suat-ngan-hang-ngay-17-10-2023-lai-suat-nhom-big4-dang-phan-hoa-ra-sao-2202992.html
# 📄 Parsing 2023-10-16 → https://vietnamnet.vn/lai-suat-ngan-hang-ngay-16-10-2023-xa-dan-muc-6-nam-2202539.html
# 📄 Parsing 2023-10-13 → https://vietnamnet.vn/lai-suat-ngan-hang-13-10-2023-ky-han-6-9-thang-ngan-hang-nao-tra-lai-cao-nhat-2201429.html
# 📄 Parsing 2023-10-12 → https://vietnamnet.vn/lai-suat-ngan-hang-12-10-2023-lai-suat-cao-nhat-11-kem-dieu-kien-gi-2200958.html
# 📄 Parsing 2023-10-11 → https://vietnamnet.vn/lai-suat-ngan-hang-11-10-2023-bidv-va-vietinbank-giam-lai-suat-huy-dong-2200525.html
# 📄 Parsing 2023-10-10 → https://vietnamnet.vn/lai-suat-ngan-hang-10-10-2023-con-nha-bang-nao-co-lai-suat-tren-6-2200061.html
# 📄 Parsing 2023-10-09 → https://vietnamnet.vn/lai-suat-ngan-hang-9-10-2023-nha-bang-ngoai-big4-dong-loat-giam-ve-duoi-5-2199625.html
# 📄 Parsing 2023-10-06 → https://vietnamnet.vn/lai-suat-ngan-hang-6-10-2023-gui-tien-ky-han-6-thang-o-dau-lai-cao-nhat-2198553.html
# 📄 Parsing 2023-10-05 → https://vietnamnet.vn/lai-suat-ngan-hang-5-10-2023-viet-a-bank-pg-bank-dieu-chinh-giam-2198111.html
# 📄 Parsing 2023-10-04 → https://vietnamnet.vn/lai-suat-ngan-hang-4-10-2023-vietcombank-giam-gpbank-bat-ngo-tang-lai-suat-2197614.html
# 📄 Parsing 2023-10-03 → https://vietnamnet.vn/lai-suat-ngan-hang-3-10-2023-lai-suat-huy-dong-tiep-tuc-giam-manh-2197088.html
# 📄 Parsing 2023-10-02 → https://vietnamnet.vn/lai-suat-ngan-hang-2-10-2023-dau-thang-10-ngan-hang-nao-co-lai-suat-cao-nhat-2196659.html
# 🔍 Page 24
# ✅ Done. Logs synced and data saved.

# %%
import os
import requests
import pandas as pd
from datetime import datetime
from pathlib import Path

# ======================================================
# CONFIG
# ======================================================
HEADERS = {"User-Agent": "Mozilla/5.0"}
SAVE_DIR = Path.cwd() / "gold_price"
SAVE_DIR.mkdir(parents=True, exist_ok=True)

CSV_FULL = SAVE_DIR / "gold_price_full_history.csv"
CSV_DAILY = SAVE_DIR / "gold_price_daily.csv"

# ======================================================
# 1️⃣ GOLD BAR (SJC miếng) — ALL TIME
# ======================================================
print("🟡 Fetching SJC gold bar data...")
url_bar = "https://cafef.vn/du-lieu/Ajax/ajaxgoldpricehistory.ashx?index=all"
resp_bar = requests.get(url_bar, headers=HEADERS, timeout=30)
resp_bar.raise_for_status()
data_bar = resp_bar.json().get("Data", {})

bar_hist = data_bar.get("goldPriceWorldHistories", [])
bar_records = [
    {
        "date": pd.to_datetime(item.get("createdAt") or item.get("lastUpdated"), errors="coerce"),
        "bar_buy": item.get("buyPrice"),
        "bar_sell": item.get("sellPrice"),
    }
    for item in bar_hist
]
df_bar = pd.DataFrame(bar_records).dropna(subset=["date"]).sort_values("date")

# ======================================================
# 2️⃣ GOLD RING (SJC nhẫn) — ALL TIME
# ======================================================
print("🔶 Fetching SJC gold ring data...")
url_ring = "https://cafef.vn/du-lieu/Ajax/AjaxGoldPriceRing.ashx?time=all&zone=11"
resp_ring = requests.get(url_ring, headers=HEADERS, timeout=30)
resp_ring.raise_for_status()
data_ring = resp_ring.json().get("Data", {})

ring_hist = data_ring.get("goldPriceWorldHistories", [])
ring_records = [
    {
        "date": pd.to_datetime(item.get("createdAt") or item.get("lastUpdated"), errors="coerce"),
        "ring_buy": item.get("buyPrice"),
        "ring_sell": item.get("sellPrice"),
    }
    for item in ring_hist
]
df_ring = pd.DataFrame(ring_records).dropna(subset=["date"]).sort_values("date")

# ======================================================
# 3️⃣ NORMALISE TIMEZONE AND MERGE
# ======================================================
df_bar["date"] = pd.to_datetime(df_bar["date"]).dt.tz_localize(None)
df_ring["date"] = pd.to_datetime(df_ring["date"]).dt.tz_localize(None)

df = pd.merge(df_bar, df_ring, on="date", how="outer").sort_values("date")

# ======================================================
# 4️⃣ CALCULATE SPREADS AND GAPS
# ======================================================
df["bar_spread"] = df["bar_sell"] - df["bar_buy"]
df["ring_spread"] = df["ring_sell"] - df["ring_buy"]
df["bar_ring_gap"] = df["bar_sell"] - df["ring_sell"]

# ======================================================
# 5️⃣ CLEAN DATA
# ======================================================
df = df.dropna(subset=["bar_buy", "bar_sell", "ring_buy", "ring_sell"], how="all")
df["date"] = pd.to_datetime(df["date"]).dt.strftime("%Y-%m-%d %H:%M")
df = df.sort_values("date").reset_index(drop=True)

print(f"✅ Cleaned data — {len(df)} rows\n")

# ======================================================
# 6️⃣ SAVE FULL DATA TO CSV
# ======================================================
df.to_csv(CSV_FULL, index=False, encoding="utf-8-sig")
print(f"💾 Saved full history → {CSV_FULL}")

# ======================================================
# 7️⃣ AGGREGATE DAILY (LAST NON-NULL VALUES)
# ======================================================
df["date_only"] = pd.to_datetime(df["date"]).dt.date
df_daily = (
    df.groupby("date_only")
    .agg({
        "bar_buy": "last",
        "bar_sell": "last",
        "ring_buy": "last",
        "ring_sell": "last"
    })
    .reset_index()
)

# Recalculate spreads and gaps
df_daily["bar_spread"] = df_daily["bar_sell"] - df_daily["bar_buy"]
df_daily["ring_spread"] = df_daily["ring_sell"] - df_daily["ring_buy"]
df_daily["bar_ring_gap"] = df_daily["bar_sell"] - df_daily["ring_sell"]

df_daily = df_daily.rename(columns={"date_only": "date"})
df_daily["date"] = pd.to_datetime(df_daily["date"]).dt.strftime("%Y-%m-%d")
df_daily = df_daily.sort_values("date").reset_index(drop=True)

# ======================================================
# 8️⃣ SAVE DAILY DATA TO CSV
# ======================================================
df_daily.to_csv(CSV_DAILY, index=False, encoding="utf-8-sig")
print(f"💾 Saved aggregated daily data → {CSV_DAILY}")
print(f"✅ Aggregated {len(df_daily)} days total\n")
# Out:
# 🟡 Fetching SJC gold bar data...
# 🔶 Fetching SJC gold ring data...
# ✅ Cleaned data — 1283 rows
#
# 💾 Saved full history → /Users/leeboo/Library/CloudStorage/OneDrive-Personal/Personal data/Study/Trading projects/Webscrapping data/market_data/bank_interest_rate/gold_price/gold_price_full_history.csv
# 💾 Saved aggregated daily data → /Users/leeboo/Library/CloudStorage/OneDrive-Personal/Personal data/Study/Trading projects/Webscrapping data/market_data/bank_interest_rate/gold_price/gold_price_daily.csv
# ✅ Aggregated 791 days total
#
# 💰 Latest update:
# 📅 Date: 2025-10-24
# 🏅 SJC gold bar sell:  148.5 triệu đồng/lượng
# 💍 SJC gold ring sell: 14850.0 triệu đồng/lượng
# 🔸 Gap (bar - ring):   -14701.50 triệu đồng/lượng
